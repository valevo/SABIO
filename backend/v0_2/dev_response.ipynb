# %%
import pandas as pd
import requests

# %%
url = "https://sabio.diginfra.net/api/v1/objects/NMvW_v0/search?object_keywords=goed&object_start_date=1950-01-01&object_end_date=&engine_id=RandomEnginev0&engine_min_score=0&engine_max_score=1&vocabulary_terms=bewindhebber%2Cbewindvoerder%2Cbomba%2Cbombay%2Ccimarron%2Cderde%20wereld%2Cdwerg%2Cexpeditie%2Cgouverneur%2Chalfbloed%2Chottentot%2Cinboorling%2Cindiaan%2Cindisch%2Cindo%2Cinheems%2Cinlander%2Cjap%2Cjappen%2Cjappenkampen%2Ckaffer%2Ckaffir%2Ckafir%2Ckoelie%2Ckolonie%2Clagelonenland%2Clandhuis%2Cmarron%2Cmarronage%2Cmissie%2Cmissionaris%2Cmoor%2Cmoors%2Cmoren%2Cmulat%2Coctroon%2Contdekken%2Contdekking%2Contdekkingsreis%2Contwikkelingsland%2Coorspronkelijk%2Coosters%2Copperhoofd%2Cori%C3%ABntaals%2Cpinda%2Cpolitionele%20actie%2Cprimitief%2Cprimitieven%2Cpygmee%2Cras%2Crasch%2Cslaaf%2Cstam%2Cstamhoofd%2Ctraditioneel%2Ctropisch%2Cwesters%2Cwilden%2Czendeling%2Czendelingen%2Czending&object_param_Classification=&object_param_Department=&engine_param_nonce=1&engine_param_redo=False"

# %%
r = requests.get(url)
# r = r.json()

# %%
r.text
# Out:
# '{"attributes":["BeginISODate","EndISODate","Department","Classification"],"results":[{"id":"497","name":"AARDEWERKEN BAKJE,VOORSTELLENDE KINDERSPEELGOED","score":0.933,"score_details":{},"thumbnail_url":"","values":["0","2001","Insulair Zuidoost-Azi\\u00eb","Materi\\u00eble cultuurcollectie"],"x":[0.0,0.994,0.5,0.4]},{"id":"524","name":"HOUTEN ORAKELBEELD MET MAGISCHE EIGENSCHAPPEN","score":0.482,"score_details":{"de":0.429,"eventueel":0.459},"thumbnail_url":"","values":["0","0","Afrika","Materi\\u00eble cultuurcollectie"],"x":[0.0,0.0,0.167,0.4]},{"id":"548","name":"Speelgoed","score":0.663,"score_details":{"Afrika":0.759,"Herk:":0.234},"thumbnail_url":"","values":["0","0","Afrika","Materi\\u00eble cultuurcollectie"],"x":[0.0,0.0,0.167,0.4]},{"id":"654","name":"HOUTEN ANTROPOMORF ORAKELBEELD MET MAGISCHE EIGENSCHAPPEN","score":0.322,"score_details":{"een":0.294,"hut":0.69},"thumbnail_url":"","values":["0","1963","Afrika","Materi\\u00eble cultuurcollectie"],"x":[0.0,0.975,0.167,0.4]},{"id":"847","name":"XYLOFOON MET 10 TOETSEN EN KALEBAS-KLANKKASTEN","score":0.421,"score_details":{"Het":0.592,"doet":0.325},"thumbnail_url":"","values":["0","0","Afrika","Materi\\u00eble cultuurcollectie"],"x":[0.0,0.0,0.167,0.4]},{"id":"1373","name":"WOONHUIS VAN DE ADMINISTRATEUR OP DE TABAKSPLANTAGE PAJA BAKONG.","score":0.617,"score_details":{"een":0.481,"van":0.538},"thumbnail_url":"","values":["1885","1888","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.936,0.937,0.5,0.2]},{"id":"1453","name":"DE VOORGALERIJ VAN HET ADMINISTRATEURSHUIS VAN C. KREBS VAN DE TABAKSONDERNEMING TOEMPATTAN VAN DE MEDAN TABAKSMAATSCHAPPIJ TE SERDANG, OOST-SUMATRA.","score":0.604,"score_details":{"die":0.321,"was":0.019},"thumbnail_url":"","values":["1890","1890","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.938,0.938,0.5,0.2]},{"id":"1972","name":"STUDIOPORTRET VAN DRIE DOCHTERS VAN HAMENGKOE BOEWONO VI, SULTAN VAN JOGJAKARTA","score":0.493,"score_details":{"benadering":0.126,"de":0.056},"thumbnail_url":"","values":["1862","1865","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.925,0.926,0.5,0.2]},{"id":"3463","name":"HET GOUVERNEMENTS GEBOUW IN CALCUTTA","score":0.386,"score_details":{"indruk.":0.127,"voorgevel":0.066},"thumbnail_url":"","values":["1863","1870","Zuid-Azi\\u00eb en vasteland Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.925,0.929,0.917,0.2]},{"id":"4298","name":"STAND MET EEN GEDEKTE TAFEL EN SERVIESGOED OP DE JAARBEURS IN BANDOENG","score":0.317,"score_details":{},"thumbnail_url":"","values":["1920","1926","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.953,0.956,0.5,0.2]},{"id":"4334","name":"TAFEL MET INGEZONDEN MARSEPEINEN SNOEPGOED VAN H.H. HOFSTEE (\\"HUIZE SCHUTTEVAER\\") UIT SOEKABOEMI OP DE JAARBEURS IN BANDOENG","score":0.551,"score_details":{},"thumbnail_url":"","values":["1920","1926","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.953,0.956,0.5,0.2]},{"id":"4336","name":"TAFEL MET INGEZONDEN MARSEPEINEN SNOEPGOED VAN \\"PATISSERIE MODERNE J.B.M. ROODESTEIN\\" OP DE JAARBEURS IN BANDOENG","score":0.682,"score_details":{},"thumbnail_url":"","values":["1920","1926","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.953,0.956,0.5,0.2]},{"id":"4343","name":"MARSEPEINEN SNOEPGOED IN DE VORM VAN EEN AUTO OP DE JAARBEURS IN BANDOENG","score":0.748,"score_details":{},"thumbnail_url":"","values":["1920","1926","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.953,0.956,0.5,0.2]},{"id":"4344","name":"TAFEL MET DOOR HOTEL DER NEDERLANDEN IN WELTEVREDEN INGEZONDEN MARSEPEINEN SNOEPGOED OP DE JAARBEURS IN BANDOENG","score":0.777,"score_details":{},"thumbnail_url":"","values":["1920","1926","Insulair Zuidoost-Azi\\u00eb","Audiovisuele collectie"],"x":[0.953,0.956,0.5,0.2]},{"id":"4699","name":"RIVIERGEZICHT BIJ LANDGOED TJIOMAS, MET EEN BRUG VAN BAMBOE IN AANBOUW, BATOETOELIS","score":0.568,"score_details":{},"thumbnail_url":"","valu ...

# %%
pd.read_json(r.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6629/2538925553.py in <module>
# ----> 1 pd.read_json(r.text)
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     612
#     613     with json_reader:
# --> 614         return json_reader.read()
#     615
#     616
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in read(self)
#     746                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     747         else:
# --> 748             obj = self._get_object_parser(self.data)
#     749         self.close()
#     750         return obj
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     768         obj = None
#     769         if typ == "frame":
# --> 770             obj = FrameParser(json, **kwargs).parse()
#     771
#     772         if typ == "series" or obj is None:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in parse(self)
#     883
#     884         else:
# --> 885             self._parse_no_numpy()
#     886
#     887         if self.obj is None:
#
# ~/.local/lib/python3.10/site-packages/pandas/io/json/_json.py in _parse_no_numpy(self)
#    1137
#    1138         if orient == "columns":
# -> 1139             self.obj = DataFrame(
#    1140                 loads(json, precise_float=self.precise_float), dtype=None
#    1141             )
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length
