# %%
from rdflib import Graph

file = "objects/ObjectsRDFXML_101.rdf"

g = Graph()
g.parse(file, format="xml")
# Out:
# <Graph identifier=N5911b8cbfafb435eb9d99c5454c730d7 (<class 'rdflib.graph.Graph'>)>

# %%
import pprint
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/207303'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/created'),
#  rdflib.term.Literal('1928'))
# (rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/2077'),
#  rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/isShownAt'),
#  rdflib.term.Literal('https://hdl.handle.net/20.500.11840/2077'))
# (rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/207527'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/extent'),
#  rdflib.term.Literal('15,6 x 21,8cm (6 1/8 x 8 9/16in.)'))
# (rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/207582'),
#  rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/provider'),
#  rdflib.term.Literal('Stichting Nationaal Museum van Wereldculturen'))
# (rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/207310'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/medium'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/termmaster26983'))
# ...

# %%
subjs, preds, objs = list(zip(*g))

# %%
set(preds)
# Out:
# {rdflib.term.URIRef('file:///home/valentin/Desktop/SABIO/data/objects/exhibition'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/creator'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/description'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/identifier'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/subject'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/title'),
#  rdflib.term.URIRef('http://purl.org/dc/elements/1.1/type'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/created'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/extent'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/medium'),
#  rdflib.term.URIRef('http://purl.org/dc/terms/spatial'),
#  rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/isRelatedTo'),
#  rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/isShownAt'),
#  rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/isShownBy'),
# ...

# %%
photo = rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/2076')

photo_triples = [(s, p, o) for s, p, o in g if s == photo]

for s, p, o in g:
    if s == photo:
        print(s)
        print('\t', p)
        print('\t\t', o)
        print()
# Out:
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/terms/spatial
# 		 https://hdl.handle.net/20.500.11840/termmaster8327
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://www.europeana.eu/schemas/edm/type
# 		 IMAGE
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/terms/created
# 		 ca. 1870
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/elements/1.1/identifier
# 		 TM-60002287
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/terms/medium
# 		 https://hdl.handle.net/20.500.11840/termmaster26012
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://www.europeana.eu/schemas/edm/isShownAt
# 		 https://hdl.handle.net/20.500.11840/2076
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/elements/1.1/identifier
# 		 2076
#
# https://hdl.handle.net/20.500.11840/2076
# 	 http://purl.org/dc/terms/extent
# 		 23,1 x 17,6cm (9 1/8 x 6 15/16in.)
#
# https://hdl.handle.net/20.500.11840/2076
# ...
