# %% [markdown]
# # First Exploration of the Wereldculturen RDF Dumps
#
# #### What do we want to do here? (*to be expanded*)
#  - (distributional) properties of objects & terms
#    - distribution over objects, object properties
#
#  - explore the properties of the collection graph & thesaurus graph:
#    - network structure (connectivity, etc)
#
#  - explore the connections between collection & thesaurus (collection links into thesaurus)
#    - intersections of entities
#    - density of indexed terms in collection
#
#
# #### TODO
#
#  - move the basic functions (such as loading the graph) into Python module

# %% [markdown]
# ### Preparation
#
# The collection data RDF dumps are too large to be uploaded to GitHub. You can get the necessary data for this notebook [here](https://collectie.wereldculturen.nl/thesaurus/#/query/89a9b00f-5f4b-4fef-bf00-32299ba16c85). Download both the collection dumps *and* the thesaurus dumps, and put the results of unzipping in folders 'objects' and 'thesaurus' respectively
#
# This notebook uses the following packages:

# %%
import glob
from tqdm import tqdm

from collections import Counter
import numpy.random as rand

import rdflib
from rdflib import Graph
from rdflib import URIRef

from tabulate import tabulate

# %% [markdown]
# ## Loading objects and thesaurus

# %%
def load_graph_from_dir(d, until=-1, file_ext="rdf", randomise=False):
    file_listing = glob.glob(f"{d}/*.{file_ext}")
    file_listing = rand.permutation(file_listing) if randomise else sorted(file_listing)
    file_listing = file_listing[:until] # there are 1570 files in /objects, loop below has 1.5 it/s so takes 15+min
    
    if len(file_listing) == 0:
        raise ValueError(f"taking {until} files from directory /{d}/ somehow not possible, listing empty!")
    
    graph = Graph()
    for path in tqdm(file_listing, 
                     desc=f"Parsing{' random' if randomise else ''} files from /{d}"): 
        graph.parse(path, format="xml")
    return graph

# %%
obj_graph = load_graph_from_dir("objects", until=10, randomise=True)
thesaurus = load_graph_from_dir("thesaurus")
# Out:
# Parsing random files from /objects: 100%|██████████| 10/10 [00:12<00:00,  1.28s/it]
# Parsing files from /thesaurus: 100%|██████████| 43/43 [00:26<00:00,  1.62it/s]

# %% [markdown]
# ---
#
# ## Dealing with Namespaces & Types

# %%
# the predicates in the object graph and the thesaurus are from these namespaces (plus others)
from rdflib.namespace import RDF, DC, DCTERMS, SKOS

# this lists all namespaces present in the graph
for ns in obj_graph.namespaces():
    print(ns)
# Out:
# ('xml', rdflib.term.URIRef('http://www.w3.org/XML/1998/namespace'))
# ('rdf', rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#'))
# ('rdfs', rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#'))
# ('xsd', rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#'))
# ('foaf', rdflib.term.URIRef('http://xmlns.com/foaf/0.1/'))
# ('edm', rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/'))
# ('dcterms', rdflib.term.URIRef('http://purl.org/dc/terms/'))
# ('dc', rdflib.term.URIRef('http://purl.org/dc/elements/1.1/'))

# %%
found_ns, found_entity = rdflib.namespace.split_uri(rdflib.term.URIRef('http://purl.org/dc/terms/alternative'))

rdflib.term.URIRef(found_ns)
# Out:
# rdflib.term.URIRef('http://purl.org/dc/terms/')

# %%
list(obj_graph.namespaces())
# Out:
# [('xml', rdflib.term.URIRef('http://www.w3.org/XML/1998/namespace')),
#  ('rdf', rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#')),
#  ('rdfs', rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#')),
#  ('xsd', rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#')),
#  ('foaf', rdflib.term.URIRef('http://xmlns.com/foaf/0.1/')),
#  ('edm', rdflib.term.URIRef('http://www.europeana.eu/schemas/edm/')),
#  ('dcterms', rdflib.term.URIRef('http://purl.org/dc/terms/')),
#  ('dc', rdflib.term.URIRef('http://purl.org/dc/elements/1.1/'))]

# %%
entities = list(type(e) for triple in obj_graph for e in triple)

# list({e for triple in obj_graph for e in triple})
# e = entities[2]

# %%
Counter(entities)
# Out:
# Counter({rdflib.term.URIRef: 228216, rdflib.term.Literal: 62214})

# %% [markdown]
# ## Querying

# %%
# extract all predicates
q = """SELECT DISTINCT ?p
       WHERE {
          # ?a ?p ?b .
       }"""

all_predicates = [row.get("p") for row in obj_graph.query(q)]

# %%
[rdflib.namespace.split_uri(p) for p in all_predicates]
# Out:
# [('http://www.europeana.eu/schemas/edm/', 'rights'),
#  ('http://purl.org/dc/elements/1.1/', 'identifier'),
#  ('http://www.europeana.eu/schemas/edm/', 'provider'),
#  ('http://purl.org/dc/elements/1.1/', 'subject'),
#  ('http://purl.org/dc/terms/', 'extent'),
#  ('http://www.europeana.eu/schemas/edm/', 'isRelatedTo'),
#  ('http://purl.org/dc/elements/1.1/', 'description'),
#  ('http://purl.org/dc/elements/1.1/', 'title'),
#  ('http://purl.org/dc/terms/', 'medium'),
#  ('http://www.europeana.eu/schemas/edm/', 'type'),
#  ('http://www.europeana.eu/schemas/edm/', 'isShownBy'),
#  ('http://purl.org/dc/terms/', 'created'),
#  ('http://www.europeana.eu/schemas/edm/', 'isShownAt'),
#  ('http://purl.org/dc/elements/1.1/', 'type'),
#  ('http://purl.org/dc/terms/', 'spatial'),
#  ('http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'type'),
#  ('http://www.europeana.eu/schemas/edm/', 'object'),
#  ('http://purl.org/dc/elements/1.1/', 'creator'),
#  ('file:///home/valentin/Desktop/SABIO/REPO/data/objects/', 'exhibition'),
#  ('http://purl.org/dc/elements/1.1/', 'isPartOf'),
#  ('http://purl.org/dc/terms/', 'alternative')]

# %%
[obj_graph.namespace_manager.qname(p) for p in all_predicates]
# Out:
# ['edm:rights',
#  'dc:identifier',
#  'edm:provider',
#  'dc:subject',
#  'dcterms:extent',
#  'edm:isRelatedTo',
#  'dc:description',
#  'dc:title',
#  'dcterms:medium',
#  'edm:type',
#  'edm:isShownBy',
#  'dcterms:created',
#  'edm:isShownAt',
#  'dc:type',
#  'dcterms:spatial',
#  'rdf:type',
#  'edm:object',
#  'dc:creator',
#  'ns1:exhibition',
#  'dc:isPartOf',
#  'dcterms:alternative']

# %%
q = """SELECT ?a ?b
       WHERE {
          # ?a dc:description ?b .
       }"""

descriptions = {obj: desc for obj, desc in obj_graph.query(q)}

# %%
descriptions
# Out:
# {rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757753'): rdflib.term.Literal('Inv.kaart:N.O.Congo (Ma-NgBetu of Lendu), cf 3015-77 en no. 779-17'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422921'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423005'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169331'): rdflib.term.Literal('Handtas die van boven dichtgetrokken kan worden met vleugelmotieven die refereren aan de Garuda, abstracte bloemmotieven, bergen en vogels. Garuda is het heilige rijdier van de indo-god Vishnu en is tegenwoordig het nationale symbool van de Republiek Indonesië Sawat (grote vleugels met staart in het midden), is een motief dat de garuda representeert. Garuda is een half-vogel, half-mensachtig wezen. Volgens de indo-Javaanse mythologie droeg Garuda Vishnu door de hemel. De Garuda is een oud koninklijk symbool (McCabe Elliot, 1984:68; Heringa, 1996:171; van Roojen, 1998:69-73). Het textiel is met goudpoeder bewerkt, vandaar prada. De reticule was eigendom van de toenmalige schoonmoeder van verzamelaar Veldhuisen.<BR>    De tas is gemaakt in een (Indo-)Europese batikkerij en was bestemd voor (Indo-)Europeanen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437346'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822984'): rdflib.term.Literal('Potje met kleurstof.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999044'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994519'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999254'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/84217'): rdflib.term.Literal('Herk: verm. Punjab of Kashmir Noord India'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757662'): rdflib.term.Literal('Pijl en boog waren de vaste wapenuitrusting van clans in West-Papoua en werden ook op het schiereiland Vogelkop veelvuldig gebruikt. Deze vaak uit bamboe, riet of hout vervaardigde wapens  gebruikten men niet alleen tijdens oorlogsvoering, maar konden ook worden benut om voedsel te vergaren door middel van jacht en namen een plek in bij verschillende rituelen.<BR>    <BR>    Grondgebied<BR>    Clans in Vogelkop verbleven niet altijd op hetzelfde gebied. Migraties vonden plaats om nieuw land te kunnen gebruiken voor het aanleggen van tuinen of het uitbreiden van het jachtgebied. Een migratie kon vredig verlopen door middel van bruiloften tussen clans. Clans die verbonden waren door huwelijken werkten nauw samen. Daardoor konden relaties tussen clans sterker zijn dan relaties binnen clans, waar politieke rivaliteit heerste. Maar er  werd ook regelmatig gevochten om grondgebied, waarbij veel slachtoffers konden vallen.<BR>    <BR>    Complexiteit van oorlog<BR>    De complexiteit van de onderlinge sociale relaties ziet men terug in de oorlogsvoering. Veel oorlogen vonden niet plaats tussen twee clans, maar tussen tijdelijke bondgenootschappen en netwerken. Hierdoor kunnen conflicten verslechteren, omdat er extra mannen bij de gevechten betrokken werden, of er rivaliteit binnen een clan kan ontstaan. Daarnaast waren wraakmoorden tussen clans niet ongebruikelijk. De nauwe banden tussen clans konden samenwerking verbeteren en conflicten verminderen, maar ook wegens de bondgenootschappen de conflictsituaties juist vergroten en verslechteren.<BR>    <BR>    Economie<BR>    In Vogelkop werd vooral gejaagd op wilde varkens, vogels en buideldieren. Daarnaast werd de voedselvoorraad aangevuld met het telen van cassave wortel of bladgroente. Door de gebergten in het gebied was niet overal vruchtbare grond, daarom kon er alleen gebruikt  gemaakt worden van niet-intensieve landbouw. Er werden veel goederen tussen clans uitgewisseld, variërend van slaven en vogels tot Kain Timur; kleding. Hierdoor bestond er al zeer lang een uitgebreid netwerk van economische relaties tussen concurrerende clanleiders. Deze gecombineerde  relaties, die bestonden uit zowel economische uitwisseling als het voeren van oorlog, wordt aangeduid met de term warrior capitalism.<BR>    <BR>    Rituelen<BR>    Naast de jacht op voedsel werden pijlen ook gebruikt voor ceremoniële jacht. Een bekend voorbeeld in West-Papoua is de ceremoniële jacht op varkens. Deze jacht gaat gepaard met diverse rituelen om de jacht succesvol te laten verlopen, waarbij gebruik gemaakt wordt van varkensstaarten (o mipi) en de varkens geesten (o mbi) goed gestemd worden. Voorafgaand aan de jacht verzamelen de jagers verkleed als varkens in een ceremonieel huis, waar offers gebracht worden aan afbeeldingen van varkens. s’Nachts vindt de jacht plaats waarbij er bij een goede jacht een stuk of tien wilde varkens gedood worden. <BR>    '),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169352'): rdflib.term.Literal('Deze jurk is gebatikt met fabelvogels, bloemen en vlinders op het sido mukti-patroon, een ruitpatroon dat is gevormd met ietwat golvende elkaar kruisende lijnen. Veldhuisen informeert dat de jurk gemaakt en gedragen werd in een Japans kamp door mevrouw Wilbrink.<BR>    De jurk is gemaakt in een Indonesische batikkerij en was bestemd voor alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169550'): rdflib.term.Literal('Groen-witte gebatikte banier met groot Arabisch schrift, bestemd voor de lokale markt. De tekst is de shahada.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437107'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169422'): rdflib.term.Literal('Bijna vierkante hoofddoek voor een man met effenblauw middenvlak met aan de randen traditionele cemukiran. Daarbuiten zijn abstracte motieven aangebracht in de rand. In het midden zit een open cirkel. De doek is gebruikt als tafelkleed.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757357'): rdflib.term.Literal("In Maluku Tenggara wordt de mens opgevat als een samenstel van twee elementen: levenskracht, verbonden met het lichaam, en identiteit, het 'eigene' van een persoon, vaak vergeleken met de ziel of geest en op veel eilanden 'schaduwbeeld' genoemd. De overtuiging bestaat dat met de dood het lichaam, verlaten door de levenskracht, vergaat en de 'schaduw' van de dode blijft voortbestaan. <BR>    Om met de overledene te kunnen communiceren, lieten de achterblijvende familieleden tot in het begin van de twintigste eeuw een houten beeldje snijden. Dit fungeerde als een zetel voor de achtergebleven 'ziel' en stelde de nabestaanden in staat de dode offers te brengen en te raadplegen; de voorouders speelden/spelen een cruciale rol opTanimbar.<BR>    In veel gevallen hadden de voorouderbeeldjes een vaste standplaats (bijvoorbeeld op de plank boven de tavu, het Tanimbarese familie-altaar), maar ook sneed men kleine, veelal mannelijke 'meeneembeeldjes' van - zoals hier - enkele centimeters groot. Deze werden meegedragen tijdens gevaarlijke geachte ondernemingen, met name oorlogen en verre handelsreizen. Hierbij fungeerden de beeldjes zowel als 'beschermengelen' als 'krachtmiddelen' om de onderneming te doen slagen.<BR>    De 'meeneem'-beeldjes werden bewaard in (gewoonlijk dichtgenaaide) tassen, die thuis aan de tavu hingen. Alleen de eigenaar mocht ze aanraken; door hun zogeheten 'hitte', een kwaliteit die dodelijk kon zijn, waren ze voor anderen te gevaarlijk. <BR>     <BR>    <BR>    <BR>    "),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822997'): rdflib.term.Literal('Ewiro is de krijger-kachina en te herkennen aan de zwart-witte beschildering met stersymbolen op zijn gezicht en aan de lange baard. Hij ziet toe op het onderhoud van de waterbronnen en andere publieke werken door de dorpsbewoners.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836589'): rdflib.term.Literal('Een kris gemaakt van gesmeed ijzer. De kris heeft een recht lemmet met en middenrug (dada), dat aan de bovenkant breed is en snel smaller uitloopt in de punt. Het lemmet heeft aan de bovenkant een opzetstuk (ganja) met aan één kant een scherpe punt met kleine uitsteeksels (greneng) en aan de andere kant een versiering. De kris heeft een komvormige greepring (selut) en een bruinhouten greep. De greep heeft een rondlopend uiteinde en is versierd met snijwerk in de vorm van uitgeholde ruitvormen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423056'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757476'): rdflib.term.Literal("Een bronzen trapplaat of fumi-e, zoals deze in het voor het buitenland afgesloten en op mogelijke christelijke invloeden bedachte Japan gebruikt werden om christenen te ontmaskeren en buiten het land te kunnen houden - dezen zouden immers niet licht op een crucifix of, zoals hier, de Madonna met kind op schoot, trappen. Dit gebruik werd in 1629 (of 1626?) voor het eerst in Nagasaki toegepast en later ook in andere regio's van het eiland Kyushu. Dergelijke bronzen fumi-e werden vooral tussen 1661 en 1673 in Nagasaki gegoten, daarvoor werden eenvoudige kruizen of heiligenafbeeldingen gebruikt. Bij de verdragen die Harris in 1858 met Japan sloot, werd het gebruik afgeschaft."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999302'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422914'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/823021'): rdflib.term.Literal('Gemaakt van het bont van een jonge klapmuts.<BR>    De haarkant is naar binnen gekeerd.<BR>    De naden zijn aan de buitenkant te zien.<BR>    <BR>    '),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999050'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836538'): rdflib.term.Literal('Klein houten hoofddeksel met goudkleurige verf.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169257'): rdflib.term.Literal('Herenoverhemd met grote motieven, zoals bladeren, ranken en bloemen. Het hemd was een geschenk aan de verzamelaar van mevrouw Kartasasmita.<BR>    De blouse is gemaakt in een Indonesische batikkerij en was bestemd voor alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994444'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423061'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169366'): rdflib.term.Literal('Op deze groene vlag is het logo van de Middelbare Landbouwschool van Yogyakarta gebatikt; erboven staan de volgende letters, \'spma\', die staan voor: \'sekolah pertanian menenga atas\' (Middelbare landbouwschool). Onder andere een korenaar en een tak met katoen (?) zijn er op afgebeeld. De doek is door Veldhuisen van een man verkregen die in 1977 een \'sentimental journey\' maakte naar Indonesië en daarbij verscheidene ex-fellows opzocht. "...Eén daarvan, Suhardi, is docent aan de Sekola Pentanian Menenga Atas in Yogyakarta. Op 13 juni 1979 stelde hij mij tijdens mijn bezoek aan de school voor aan de directeur die mij deze vlag overhandigde. Dat is alles wat mij ervan bekend is".<BR>    De doek is gemaakt in een Indonesische batikkerij en was bestemd voor Indonesië.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422704'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423041'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437348'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994463'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822801'): rdflib.term.Literal('Prent van gedenksteen met tekst'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437310'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/998992'): rdflib.term.Literal('Foto genomen tijdens het bezoek van de gouverneur-generaal. De demang van Tibatang draagt een Nederlandse onderscheiding, te weten een gouden Ster voor Trouw en Verdienste. De demang kreeg deze onderscheiding voor zijn houding tijdens de onlusten in 1908. <BR>    <BR>    De ster voor Trouw en Verdienste was een onderscheiding binnen het Nederlandse koloniale systeem voor “aanzienlijke en verdienstelijke Inlanders en Oostersche vreemdelingen”. Er waren gouden, zilveren en bronzen sterren in de varianten groot en klein.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822973'): rdflib.term.Literal('Glazen staafje. Geen verdere informatie.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994755'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836929'): rdflib.term.Literal('Dit type kano met uitlegger komt uit Sialum in de provincie Morobe (Papua Nieuw-Guinea). Met dergelijke vijf meterlange kano’s wordt op zee gevaren. De boten worden in een specifieke functie gewijd. Zo kan een kano ‘Heer van de vissen’ worden genoemd om een goede visvangst te garanderen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999436'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422845'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822601'): rdflib.term.Literal('Een vierdelige lamp?'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999378'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169235'): rdflib.term.Literal("Wikkelrok met apotropeïsche poleng-motief, een zwart-wit schaakbordpatroon dat beschermende kwaliteiten heeft. Daarop zijn Nederlandse Kronen onder elkaar gebatikt. Links en rechts daarvan bevinden zich naga's, oorspronkelijk het symbool van de onderwereld (McCabe Elliot, 1984:68). De rok is gemaakt in een lokale batikkerij en was bestemd voor Indonesië."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836919'): rdflib.term.Literal('Uit één stuk donker hout en verschillende uitvoering.<BR>    1363: Het voetstuk wordt gevormd door vier op elkaar liggende en steeds kleiner wordende afgeronde zeshoeken, het onderste deel is ruw rond- ovaal met een putje in het midden. Op dit voetstuk rust de halvemaanvormige legger, in het midden het breedst naar de oplopende einden smaller en rond bijgewerkt, aan één zijde in legger en voetstuk een gleuf, aangevreten door insekten o.d.<BR>    1363a: langwerpig voetstuk, smalle kanten afgerond, hierop staan in lengterichting een dubbelmensfiguur zonder benen in kruiphouding. In het midden gesteund door een door het lichaam lopend paaltje, armen van mensfiguur naar binnen gebogen, langwerpig hoofd, aan een zijde beschadigd. Hierop een halvemaanvormige legger, aan de onderzijde met een opengewerkte rug aan beide zijden.<BR>    Bovenzijde van de legger met een verdikking welke aan een zijde aan een kant besneden is, daarboven plat rechthoekig met doorboorde gaatjes aan beide zijden.<BR>    <BR>    In plaats van een hoofdkussen maakte de inheemse bevolking van de Geelvinkbaai gebruik van de neksteun die overal mee naartoe genomen werden. Hoewel het voorwerp een neksteun wordt genoemd werd niet liggend met de nek, maar met het oor erop geslapen. De neksteunen werden over het algemeen uit één blok hout gesneden. De oorspronkelijke verzamelaar merkte op dat in de islamitische gebieden de bevolking op hoofdkussens sliep. De figuren die in de neksteunen zijn gesneden stellen vaak voorouders of het clan embleem voor. Tijdens de slaap geven deze krachten bescherming en hulp aan de slaper.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169602'): rdflib.term.Literal('Vrij brede schouderdoek, met florale motieven en fabelvogels op een cocohan achtergrond (verkregen door met een naald in de waslaag te prikken). Volgens de verzamelaar is de doek een combinatie van commerciële en lokale Noordkust batik. De doek heeft een imitatiekanten rand: booh. Op een papiertje bij de registratie van de verzamelaar Veldhuisen staat de naam van een batikster vermeld: Rugayah, het is niet duidelijk of zij deze doek vervaardigd heeft; waarschijnlijk (zie ook doeken inv.nrs. 5663-220 en 221). Een selendang is een typisch vrouwenkledingstuk en wordt vaak gebruikt voor het dragen van kinderen of voorwerpen. De doek was bestemd voor gebruik door alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423069'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437365'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822600'): rdflib.term.Literal('Een vierdelige lamp?'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994691'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757562'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437248'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169397'): rdflib.term.Literal("Bijna vierkant tafelkleed met in het midden een cirkelvorm met driehoekjes (tumpal. Daar omheen weer een grotere cirkel met driehoekjes, dit keer naar binnen gekeerd. Daar omheen zijn motieven afgebeeld als vogels, bloemranken en vleugels, die tezamen het semèn-motief vormen.<BR>    Het semèn-motief is een geheel aan symbolische motieven die verwijzen naar de betekenis van het woord: 'ontspruiten', of 'groeien'. Dit motief bevat zoveel symboliek dat het zowel staat voor vruchtbaarheid, als voor het Javaanse geloof in een kosmische orde (McCabe Elliot, 1984:68). <BR>    De doek is gemaakt in een (Indo-)Europese batikkerij en was bestemd voor (Indo-)Europeanen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169267'): rdflib.term.Literal('Overhemd met korte mouwen en gebatikt met sawat (mirong volgens Veldhuisen), vleugelparen met uitwaaierende staarten ertussen. Sawat (grote vleugels met staart in het midden), is een motief dat de garuda representeert. Garuda is een half-vogel, half-mensachtig wezen. Volgens de Indo-Javaanse mythologie droeg Garuda Vishnu door de hemel. De Garuda is een oud koninklijk symbool (McCabe Elliot, 1984:68; van Roojen, 1998:69-73; Heringa, 1996:171).<BR>    De blouse is gemaakt in een Indonesische batikkerij (label: Ganapati) en was bestemd voor alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994637'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822618'): rdflib.term.Literal('Een brede staaf voor shiskebab.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422771'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422968'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836899'): rdflib.term.Literal('Uit twee stukken bamboe, waarvan een kort deel de inschuivende deksel vormt. Beiden door een naar binnen vallend tussenschot gesloten deksel. Plat afgesneden op enkele cm. van het knop einde zijn rondlopende ringen ingesneden, daartussen kleinere versieringen van snijwerk.<BR>    <BR>    Het kauwen van de betelnoot is een wijdverbreid fenomeen in Melanesië. Het betelmengsel bestaat uit de noot van de arecapalm, de vrucht of de noten van de betelpeper (Piper betle en verwante soorten) en een soort kalk dat een mengsel is van verbrand koraal en vermalen kalksteen. Het kauwen hiervan heeft een stimulerend effect; het verdrijft de vermoeidheid en honger. Door veelvuldig gebruik kleuren de tanden rood. De kalk werd bewaard in speciale bamboekokers. De kokers werden vaak versierd met ingekraste patronen. Ook kalebassen konden als kalkhouder dienen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757768'): rdflib.term.Literal('Inv.kaart: Congo (Kassai) Cf 3015-68 zie ook no. 595-30'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169487'): rdflib.term.Literal("Een paarsrode schouderdoek met halve kepala ('hoofd') aan elk uiteinde die de traditionele tumpal bevatten. De papan en rest van de doek, de badan ('lichaam'), zijn gebatikt met florale motieven op een achtergrond van stippen.<BR>    De doek is gemaakt in een Indonesische batikkerij en was bestemd voor Indonesiërs."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437456'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169340'): rdflib.term.Literal('Muurdecoratie met bruin vlak waarin verticale lijnen zijn afgebeeld, die bovenaan beginnen met een kawung-variant. De kawung behoort tot de zogenaamde verboden motieven, die door de sultans van Midden-Java in de 18e eeuw werden uitgeroepen tot koninklijke symbolen, en derhalve verboden waren voor het gewone volk (McCabe Elliot, 1984:68).<BR>    Onderaan het bruine vlak zijn een drietal abstracte vlinders gebatikt; prada is gebruikt om de doek verder te versieren. De doek is een typische Art Nouveaustijl gemaakt. Dit is een stijl die rond 1900 werd ontwikkeld door Nederlandse kunstenaars die met batik werkten (zie van Hout, 2001).<BR>    De doek is gemaakt in een (Indo-)Europese batikkerij en was bestemd voor (Indo-)Europeanen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169526'): rdflib.term.Literal('deze borstdoek heeft een effenrood middenvlak met cemukiran aan de binnenzijden. De rand bestaat uit diagonale banen, garis miring, die gevuld zijn met parang-motieven. Het parang motief is één van de zogenaamde verboden motieven. Deze motieven werden door de sultans van Yogya en Solo verboden voor de gewone burgers te dragen. Parang betekent (klein) zwaard, en symboliseert macht en groei (McCabe Elliot, 1984:68).<BR>    De doek is gemaakt door en voor de lokale bevolking.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437160'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994538'): rdflib.term.Literal('Bloemencorso Buitenzorg.     De Jong'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999391'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437407'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/892805'): rdflib.term.Literal('Inuitdansers.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994473'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999142'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169577'): rdflib.term.Literal('Tjioe Tjat Kwee'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169579'): rdflib.term.Literal("Een nu opengemaakte kokerrok in Europese stijl: bloemboeketten (buketan) in bordeauxrood, rose, twee tinten groen, paars en lichtbruin en wit.  Boeketten zijn oorspronkelijke echt Europese motieven, maar werden snel populair onder Indo-Chinezen, vooral na hun wettelijke gelijkstelling in 1920 aan de (Indo-)Europeanen, als statussymbool (Heringa, 1996). Voorgestelde bloemen zijn rozen en chrysanten. Er boven vliegen vogels en vlinders. De kepala ('hoofd') heeft kleine bloemetjes op de achtergrond, terwijl de badan ('lichaam') driemaal het motief van de kepala bevat, zonder die bloemetjes. De doek is gemaakt door (Indo-)Chinezen en was bestemd voor alle culturele groepen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999198'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994768'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422933'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437265'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169324'): rdflib.term.Literal('Een doek met een geheel aan symmetrisch gerangschikte dieren: olifanten, leeuwen en pauwen, op een achtergrond van stippen.<BR>    De doek is gemaakt in een locale batikkerij en was bestemd voor Indonesiërs.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422941'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169314'): rdflib.term.Literal("Donkerblauwe stof met witte motieven. Op de stof zijn all vijf, bredere en smallere, stropdassen gebatikt. Motieven zijn floraal met Chinese vlinders, maar ook semèn, met vleugelmotieven, dieren en bergen (gunung). Het semèn-motief is een geheel aan symbolische motieven die verwijzen naar de betekenis van het woord: 'ontspruiten', of 'groeien'. Dit motief bevat zoveel symboliek dat het zowel staat voor vruchtbaarheid, als voor het Javaanse geloof in een kosmische orde (McCabe Elliot, 1984:68). Veldhuisen noemt de dubbele vleugelmotieven mirong, doch in literatuur staat dit motief, namelijk met uitwaaierende staart ertussen, bekend als sawat. Sawat (grote vleugels met staart in het midden), is een motief dat de garuda representeert. Garuda is een half-vogel, half-mensachtig wezen. Volgens de indo-Javaanse mythologie droeg Garuda Vishnu door de hemel. De Garuda is een oud koninklijk symbool (idem; Heringa, 1996:171; van Roojen, 1998:69-73).<BR>    De rok is gemaakt in een Indo-Chinese batikkerij en was bestemd voor (Indo-)Europeanen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994434'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422832'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437441'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994729'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757769'): rdflib.term.Literal('Inv.kaart: Congo  Cf 3015-93 zie ook no.1259-40'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999166'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169546'): rdflib.term.Literal('Een aaneengenaaide kokerrok met roze badan en groene kepala, gevuld met grote boeketten orchideeën waarboven vlinders vliegen. Boeketten (buket) zijn echte Europese motieven, die na de wettelijke gelijkstelling van Chinese immigranten en Peranakan aan de (Indo-)Europeanen in 1920 veelvuldig gebruikt werden door die bevolkingsgroepen om zo hun hoge status kenbaar te maken. De afgebeelde bloemen zijn orchideeën volgens de verzamelaar Veldhuisen, en deze bloemen hebben voor Peranakan een brede variatie aan associaties: ze zijn embleem van de liefde, schoonheid en een groot nageslacht (idem). Vlinders staan in de Chinese symboliek voor een gelukkig huwelijk (Heringa, 1996). Na verloop van tijd werden de luxueuze kwaliteiten van de Peranakan batiks en een overvloed aan kleur belangrijker in het toekennen van status dan de gebruikte symboliek (Heringa, 1996). Deze doek was bestemd voor Chinese afneemsters en voor de export.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/88216'): rdflib.term.Literal('Herk: Mexico Midden Amerika'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169263'): rdflib.term.Literal('Herenoverhemd met diagonale banen (garis miring) met afwisselend bloemen en bladeren en het traditionele parang-motief. Het parang motief is één van de zogenaamde verboden motieven. Deze motieven werden door de sultans van Yogya en Solo verboden voor de gewone burgers te dragen. Parang betekent (klein) zwaard, en symboliseert macht en groei (McCabe Elliot, 1984:68). De stof is gekocht op de pasar Bringharjo te Yogyakarta.<BR>    De blouse is gemaakt van een kain panjang (uit een Indonesische batikkerij) die van de Pasar Bringharjo te Yogyakarta kwam en was bestemd voor Indonesiërs.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994576'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437126'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994398'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/78204'): rdflib.term.Literal('De Ashanti danken hun opkomst en rijkdom aan de exploitatie van enorme goudbronnen. Om het goud te wegen gebruikten ze kleine bronzen of messingen gewichtjes in de vorm van dieren, insecten, voorwerpen en taferelen uit het dagelijkse leven. Soms werden gewichtjes in Europa gemaakt en naar het huidige Ghana verscheept.<BR>    Hoewel goud tegenwoordig is vervangen door een Westerse vorm van ruilmiddel, bevinden dergelijke gewichtjes, kleine weegschalen, goudstofdoosjes en scheplepeltjes zich nog in de huizen van mensen of in de schatkamers van koningen en hoofdmannen. Er bestaat nog een handvol vervaardigers van de gewichtjes. <BR>    Elke man die zich bezighield met de goudhandel, bezat een aantal van deze gewichtjes. In sommige gebieden behoorden ze tot de geschenken die een vader zijn zoon gaf bij het volwassen worden. <BR>    Als ze niet gebruikt werden, werden de gewichtjes en bijbehorende voorwerpen in doeken gewikkeld en goed bewaard. Hieruit blijkt de hoge waarde die aan de gewichten werd toegekend, alsmede de reden waarom er nog zoveel van de gewichtjes bewaard zijn gebleven. De gewichtjes waren niet alleen belangrijk bij de goudhandel, maar tevens als erfgoed voor volgende generaties. Ook waren sommige ooit eigendom van overwonnen vijanden, terwijl andere als model kunnen hebben gefunctioneerd voor de koninklijke regalia die ze representeren.<BR>    Een enkele keer werd een persoon met zijn gewichtjes begraven. Het bepalen van de ouderdom van de voorwerpen is vanwege al voornoemde niet gemakkelijk.<BR>    In principe werden bij de Ashanti twee soorten goudgewichten gebruikt: harde zaden, en metalen gewichtjes. De laatstgenoemde, meestal koperen, gewichtjes bestonden uit twee brede categorieën, te weten de realistische weergaven, en de meer abstracte vormen. <BR>    Er is geen relatie tussen de voorstelling en de waarde van een gewichtje. Er bestond een algemeen aanvaarde theorie over de waarde van gewichtjes, en verder werd de waarde bepaald door de eigenaar, afhankelijk van de betekenis van het voorwerp voor hem en zijn familie. <BR>    Bepaalde patronen waren voorbehouden aan de koninklijke familie, zoals regalia, textielpatronen en stoelen. De traditionele betekenissen van gewichtjes zijn moeilijk te achterhalen, met name in geval van geometrische motieven. Figuratieve voorbeelden stellen vaak een spreekwoord voor. Echter, vaak komen meer dan een spreekwoord in aanmerking voor duiding, waarvan sommige lijnrecht tegenover elkaar staan. Kennis van spreekwoorden was een teken van senioriteit en wijsheid en was het terrein van koningen en hun okyeame, hun sprekers, die als medium tussen een hoofdman en zijn volk stonden.<BR>    Vanaf de jaren 1920 werden gewichtjes alleen nog gemaakt voor de verkoop aan Europeanen. Naast het wegen werden de gewichten ook gebruikt door vertellers om hun verhalen te illustreren. Ook werden ze wel gedragen als talisman of sieraad.<BR>    <BR>    Vervaardiging<BR>    Voor het maken van metalen gewichtjes gebruikten de Akan-smeden twee methoden: ten eerste maakte men modellen van echte voorwerpen door er een kleimengsel omheen te vormen, waarna men via een smalle doorgang het gesmolten koper naar het object toevoerde. In een oven zou het oorspronkelijke voorwerp verbranden, waarna het metaal zijn vorm aan zou nemen. Ten tweede was er de à cire perdue methode, waarbij een model gemaakt werd in bijenwas, omgeven met het kleimengsel en tenslotte de bijenwas werd weggesmolten in een oven.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822729'): rdflib.term.Literal('het gaat hier alleen om het album'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169500'): rdflib.term.Literal("De kepala ('hoofd') heeft een sierlijke diagonale baan in het midden met florale motieven. In de hoeken van de kepala staat een sierlijke fabelvogel op een bilik-achtergrond. Bilik lijkt op vlechtwerk. De badan ('lichaam') van de rok vormt een geometrisch geheel van semèn-motieven. Het semèn-motief is een geheel aan symbolische motieven die verwijzen naar de betekenis van het woord: 'ontspruiten', of 'groeien'. Dit motief bevat zoveel symboliek dat het zowel staat voor vruchtbaarheid, als voor het Javaanse geloof in een kosmische orde (McCabe Elliot, 1984:68). Hier zijn vleugelmotieven als lar (enkele vleugel) en sawat (dubbele vleugels met uitwaaierende staart er tussen in), die refereren aan de Garuda, heilig rijdier van Hindoegod Vishnu en nationaal symbool van de huidige Republiek Indonesië (Heringa, 1996:171), bergen (gunung), vogels en insecten.<BR>    De doek is gemaakt in een lokale batikkerij en was bestemd voor alle culturele groepen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836527'): rdflib.term.Literal('Metalen stempel behorende bij de serie Taoïstische rolschilderingen van het Yao volk, gemaakt in Zuid-China (Guangxi). Een kandidaat van tenminste de Tou Sai ceremonie, krijgt deze regel na de inwijding, samen met een document (tieh). Deze kan hij gebruiken bij het in de toekomst te schrijven petities die naar de hemel gestuurd worden. Deze regel is vermoedelijk van een hoge priester. Op de regel staat:<BR>    "De Yuan schat van de Taoïstische canon".'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757400'): rdflib.term.Literal('Dansschortje, een vrijwel vierkante lap bestaande uit twee lagen, een laag grove bruine boombast en daarop een laag bruin vezel- weefsel; rond de gehele lap is een snoer grijswitte vruchtjes vast- gemaakt en verder is langs de gehele rand een dubbele en aan de onderrand een drievoudige rij van aaneengesloten nassaschelpjes vastgeregen; op het middenveld zijn in nassaschelpjes twee mensenfiguurtjes gestikt, beide gelijk in zittende houding met hoogopgetrokken knieën en omhooggeheven armen; gezicht en oren zijn door gele, rode en groene kraaltjes voorgesteld; rond de tegenelkaar liggende onderarmen een dubbel snoer van kraaltjes, hetzelfde rond de onderbruik. Het vermoedelijk mannelijk schaam- deel is bij de ene figuur voorgesteld door een rode en twee gele.<BR>    Langs de onderrand aan een met kralen versierd touwtje hangen dertien metalen gemakkelijk rinkelende belletjes; van één van deze belletjes is een stukje afgebroken.<BR>    Tot de draagband dient een snoer van rode en enkele groene vruchtjes.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/88730'): rdflib.term.Literal('Credits: Dr. Hans Feriz'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836535'): rdflib.term.Literal('Houten stempel met paardenfiguren uitgesneden.<BR>    Gebruikt bij het maken van papier geld.<BR>    Rechthoekig van vorm, met touwtje aan een uiteinde.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437296'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999094'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822781'): rdflib.term.Literal('Zwart-witte prent op papier'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169596'): rdflib.term.Literal("Gesloten kokerrok met motieven die verkregen zijn door een speciale weeftechniek. Hierdoor zijn vierkantjes verkregen, die in de kepala ('hoofd') groter zijn dan op de badan ('lichaam'). De doek is vervaardigd voor de lokale markt."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822611'): rdflib.term.Literal('Zittende figuur, hand gevormd.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/823006'): rdflib.term.Literal('Wanneer we naar maskers uit het Sepik gebied kijken moeten we in gedachten houden dat deze maskers gepaard gingen met weldadig versierde lichamen en uitbundig dansende participanten tijdens de vele ceremoniële feesten die in de Sepik samenlevingen plaats vonden. De geverfde gezichten en met veren en schelpen versierde borstkassen en ledematen bieden een zeer andere verschijning dan de menselijke lichamen in het dagelijks leven. Maskers konden zowel worden gebruikt om de gevel van het ceremoniële huis te versieren, als om werkelijk gedragen te worden tijdens rituelen. Er bestaan zeer veel verschillende soorten kunstobjecten in het Sepik-gebied. Deze diversiteit wijst op een rijke geschiedenis van contacten en uitwisselingen, in de vorm van oorlog, dominantie en aanpassing. Ook zijn historische en ecologische gebeurtenissen de oorzaak van het verplaatsen van verschillende bevolkingsgroepen naar andere provincies, die hiermee hun eigen traditionele objecten verspreidden. Metaal was lange tijden onbekend in Papoea, maar alle materialen die voorhanden waren werden voor de objecten gebruikt. Van veren, schelpen en bladeren tot bamboe en verschillende houtsoorten, van dierentanden tot de snavel van een neushoornvogel of een menselijke schedel, in combinatie met verf, gemaakt van verschillende materialen. <BR>    <BR>    Ceremoniële mannenhuis: Het centrum van rituele en politieke macht was het ceremoniële mannenhuis, waar alle mannen georganiseerd waren in groepen naar leeftijd en initiatie.  Voordat de Britten vrede aan de volkeren oplegden, was het mannenhuis ook een representatie van de strijdkrachten van een dorp. Het ceremoniële huis wordt tevens gezien als een verschijningsvorm van de wereld van de voorouders. Er werd gedacht dat de voorouders altijd rond het huis aanwezig waren.  Dit kon onder het huis zijn, in de vorm van krokodillen. Als de voorouders namen opgenoemd werden tijdens ceremoniën wordt er een link gelegd tussen de echte wereld en de wereld van de voorouderen. De belangrijkste mythe van de Sepik vertelt het verhaal van de voorouder-krokodil die de vaste grond creëerde door met zijn staart op het water te slaan. Hierdoor ontstond er een goede leefomgeving voor de volkeren van de Sepik, met natuurlijke dijken rondom de oever van de rivier. Elke clan heeft nog steeds een identiteit op basis van de voorouderkrokodil. Rituelen zijn een manier om de connectie tussen de mens en de tijd van de creatie van het leven in stand te houden. Dit verbond wordt van tijd tot tijd vernieuwd door middel van initiatie-ceremonieën. Tijdens deze ceremoniën gaan jonge mannen van de moederswereld naar de wereld van de vaders, de mannen; van het familiehuis naar het mannenhuis.<BR>    <BR>    Mwai-maskers: Voor het ritueel krijgen de jongens eerst een maandenlange training waarin zij onder andere leren muziekinstrumenten te bespelen. Zij leren alles wat nodig is om een ceremonie te organiseren en het laten verschijnen van verschillende soorten maskers. De zogeheten Mwai-maskers is het eerste type maskers waar de jongens mee dansen. Mwai maskers zijn vaak langwerpige kleurrijke houten maskers. Niet de eigenaar van het masker zelf, maar zijn jongere broer die geïnitieerd wordt draagt het masker. In sommige lagere Sepik gebieden werden ook meisjes geïnitieerd. De ceremoniën bereidden de jongeren voor op hun verantwoordelijkheden en plichten als jager en krijger.<BR>    <BR>    Verschijningsvorm: Er zijn verschillende soorten maskers. Maskers met een lange puntige neus worden ‘mosquito’ maskers genoemd. Dit is in werkelijkheid een directe verwijzing naar een mannelijke geest (spirit) genaamd parak of brag. De parak geest is nauw betrokken bij initiatie ceremonies van de jonge mannen in wording en bij het jagen. Er wordt gedacht dat de parak het spel toont aan de jager, terwijl hij het verborgen houdt voor vreemden. Van oorsprong komen dergelijke maskers ui ...
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423021'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169463'): rdflib.term.Literal('Op deze wanddecoratie staan, in liggend formaat, vijf wayangfiguren afgebeeld, waarvan één groter is dan de overige. <BR>    De doek is gemaakt in een Indonesische batikkerij en was bestemd voor alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437171'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422787'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/68789'): rdflib.term.Literal('De goudkleurige draden van het lancé-inslagstelsel die het goudkleurige ornament vormen, bestaan uit een katoenen kern die is omwikkeld met goud.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994437'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/88682'): rdflib.term.Literal('Credits: Dr. Hans Feriz'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836878'): rdflib.term.Literal('Van bamboe, het naar binnen gebogen tussenschot als bodem, en de buitenonderkant schuin bijgewerkt. De gehele koker is met snijwerk versierd. Bij B+ alleen de bovenkant, onderkant schuin bijgesneden.<BR>    1295= over de gehele lengte gebarsten en wordt bovenaan met een ijzerdraad bijeengehouden.<BR>    A: is met een overschuivend deksel zie foto.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422666'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994733'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169348'): rdflib.term.Literal('Winotosastro Yogya Indonesia'),
# ...
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169382'): rdflib.term.Literal('fa. H. Bilal'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437206'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994548'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999322'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422897'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169334'): rdflib.term.Literal('Kinderwikkelrok met parang-motief, behorende bij een setje met een hoofddoek (voor jongens). Het parang motief is één van de zogenaamde verboden motieven. Deze motieven werden door de sultans van Yogya en Solo verboden voor de gewone burgers te dragen. Parang betekent (klein) zwaard, en symboliseert macht en groei (McCabe Elliot, 1984:68).<BR>    De doek is gemaakt in een (Indo-)Europese batikkerij en was bestemd voor (Indo-)Europeanen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994428'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169527'): rdflib.term.Literal('Nj. Tjoa Tjoen Tiang'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437140'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822703'): rdflib.term.Literal('het gaat hier alleen om het album en niet het eerste blad'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437211'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994776'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757350'): rdflib.term.Literal("In Maluku Tenggara wordt de mens opgevat als een samenstel van twee elementen: levenskracht, verbonden met het lichaam, en identiteit, het 'eigene' van een persoon, vaak vergeleken met de ziel of geest en op veel eilanden 'schaduwbeeld' genoemd. De overtuiging bestaat dat met de dood het lichaam, verlaten door de levenskracht, vergaat en de 'schaduw' van de dode blijft voortbestaan. <BR>    Om met de overledene te kunnen communiceren, lieten de achterblijvende familieleden tot in het begin van de twintigste eeuw een houten beeldje snijden. Dit fungeerde als een zetel voor de achtergebleven 'ziel' en stelde de nabestaanden in staat de dode offers te brengen en te raadplegen; de voorouders speelden/spelen een cruciale rol opTanimbar.<BR>    In veel gevallen hadden de voorouderbeeldjes een vaste standplaats (bijvoorbeeld op de plank boven de tavu, het Tanimbarese familie-altaar), maar ook sneed men kleine, veelal mannelijke 'meeneembeeldjes' van - zoals hier - enkele centimeters groot. Deze werden meegedragen tijdens gevaarlijke geachte ondernemingen, met name oorlogen en verre handelsreizen. Hierbij fungeerden de beeldjes zowel als 'beschermengelen' als 'krachtmiddelen' om de onderneming te doen slagen.<BR>    De 'meeneem'-beeldjes werden bewaard in (gewoonlijk dichtgenaaide) tassen, die thuis aan de tavu hingen. Alleen de eigenaar mocht ze aanraken; door hun zogeheten 'hitte', een kwaliteit die dodelijk kon zijn, waren ze voor anderen te gevaarlijk. <BR>     <BR>    <BR>    <BR>    "),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999411'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169167'): rdflib.term.Literal('Bijna vierkant kussen met in het midden twee naar elkaar gerichte wayangfiguren op een stenen muurtje. Ze zijn afgebeeld binnen een sierlijke rand met florale motieven en ook Garudavleugels (mirong volgens Veldhuisen).<BR>    Het kussentje is gemaakt in een lokale batikkerij voor (Indo-)Europeanen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822733'): rdflib.term.Literal('in vouwvorm'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757526'): rdflib.term.Literal('Een schaakstuk in de vorm van een een olifant met twee berijders.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422988'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169478'): rdflib.term.Literal("In het midden van dit wandkleed staat een stervorm die is opgebouwd uit acht bloemen. Er omheen staan, met de hoofden steeds naar het middenmotief gericht, vier wayangfiguren, afgewisseld door tweekoppige garuda's. De rand is gebatikt in florale motieven.<BR>    De doek is gemaakt in een Indonesische batikkerij en was bestemd voor alle culturele groepen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437229'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999374'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169432'): rdflib.term.Literal('Pareamon'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822995'): rdflib.term.Literal('Kachinas zijn geesten die bemiddelen tussen mensen en goden. Ze brengen regen en zonneschijn, helpen mensen persoonlijk maar straffen overtreders. Het is daarom belangrijk ze te vriend te houden. Iedere winter houden Pueblo ceremonies met gemaskerde dansers die de kachinas verbeelden.<BR>De kachina-cultus bestaat uit een reeks dansen. Gemaskerde dansers beelden ieder een specifieke kachina uit. Tijdens de dans neemt die kachina bezit van de danser. De verschillende kachinas zijn te herkennen aan vormen, kleuren en symbolen zoals lichaamsbeschildering, kleding, voorwerpen die ze bij zich dragen - dansstokken, dansplanken -, geluiden die ze maken, de vorm van het hoofd of delen daarvan. De sprinkhaan is één van de weinige kachinas die geen typerende attributen meedraagt.', lang='ned'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994634'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994807'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/836539'): rdflib.term.Literal('Stapeltje papiergeld behorende bij de rituele attributen van het Yao volk.<BR>    Een bundel papiergeld bestaat uit 2 x 1, 1 x 2, 1 x 4 = 8 briefjes met een grasspriet/riet bijeen gehouden.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822970'): rdflib.term.Literal('Blik met kajal.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999144'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169440'): rdflib.term.Literal("Crème- en roodkleurige gesloten kokerrok door Peranakan (Indo-Chinezen) vervaardigde doek met rode kepala en crème badan. De kepala ('hoofd') heeft een groot u-vormig plantmotief, met koren/rijstaren aan de takken. Er tussen vliegt de mythische vogel feniks, een typisch Chinees symbool voor zomer, oogst, en welvaart (Heringa, 1996). Op de achtergrond zijn kleine bloemen afgebeeld. De badan ('lichaam') bevat, diagonaal gebatikt, grote bloemen (die lijken op eikenblad) en druiventrossen op een achtergrond van ukel (kleine krullerige ranken). Aan de bovenkant van de rok is een witte katoenen band bevestigd. Korenaren, of maiskolven, waren niet aan iedereen bekend; door hen werden deze motieven gezien als rijstaren. Ze refereren aan de oogsttijd. De doek bevat imitatiekanten randen: booh (Heringa, 1996), en was bestemd voor alle culturele groepen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/422909'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/76934'): rdflib.term.Literal('De Asmat droegen, net als veel andere Papua- volkeren sieraden door hun neus, niet alleen bij ceremoniële gelegenheden, maar ook in het alledaagse leven. De versierselen bevestigden hun status als krijger, koppensneller of jager. Er zijn twee soorten neussieraden: die van schelp met gekrulde vorm – af en toe ook gedragen als borstsieraad – en die van been met een langwerpige vorm.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/822710'): rdflib.term.Literal('het gaat hier alleen om het album en niet het eerste blad'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437105'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437257'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757568'): rdflib.term.Literal('Gipsafgietsel van lettertype in de taal van de Oeigoeren, het origineel is gevonden in Turkestan (China).'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994598'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169347'): rdflib.term.Literal('Wandkleed met een pronkende pauw in het midden, en twee pauwen die op hun zijde zijn afgebeeld. Er omheen is een rand van bladeren gebatikt, met in de hoeken de sawat. Sawat (grote vleugels met staart in het midden), is een motief dat de garuda representeert. Garuda is een half-vogel, half-mensachtig wezen. Volgens de indo-Javaanse mythologie droeg Garuda Vishnu door de hemel. De Garuda is een oud koninklijk symbool (Mc Cabe Elliot, 1984:68; Heringa, 1996:171; van Roojen, 1998:69-73).<BR>    De doek is gemaakt in een Indonesische batikkerij en was bestemd voor alle culturele groepen.'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999070'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437292'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/999361'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437261'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169421'): rdflib.term.Literal("Zowat vierkante mannenhoofddoek met effenblauw middenvlak (modang volgens Veldhuisen, hoewel normaliter modang ruitvormig zijn). De rand is gebatikt met pauwen, bomen, bloemen, vogels en een rijstmotief, beras wutah. Veldhuisen noemt het geheel semèn. Het semèn-motief is een geheel aan symbolische motieven die verwijzen naar de betekenis van het woord: 'ontspruiten', of 'groeien'. Dit motief bevat zoveel symboliek dat het zowel staat voor vruchtbaarheid, als voor het Javaanse geloof in een kosmische orde (McCabe Elliot, 1984:68).<BR>    De doek is in kratonstijl gebatikt en is gemaakt door en voor Indonesiërs."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169499'): rdflib.term.Literal('Nj. Tjoa Cioa Tjiam'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/437367'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169350'): rdflib.term.Literal("Europese kindersarung in rood en wit (bang bangan) met florale motieven. De kepala ('hoofd') is in Europese stijl, dus zonder tumpal en papan, en met imitatie-kanten sierrands (booh). Zulke sierrands zitten ook aan de randen van de badan ('lichaam'). De kepala bevat verder motieven als kleine boeketten (buket), anjers, geometrische bloemen. De badan bevat pohon: (levens-)boom, grote bloemen aan ranken (lotus?) en verschillende siervogels, met een helft ondersteboven. De levensboom vormt het centrum van de wereldlijke orde, en is het medium tussen de onderwereld van de voorouders en de bovenwereld van de mens, met name tijdens belangrijke gebeurtenissen in een mensenleven. Anjers verwijzen naar fijngevoeligheid, en de afgebeelde vogels kunnen geïnspireerd zijn door de mythische feniks, die welvaart symboliseert (Heringa, 1996). De lotus staat voor reïncarnatie en de voortzetting van de familiestamboom. De kruipende ranken zijn lung-lungan, volgens een aangehecht kaartje aan de registratie van de verzamelaar. Boeketten zijn echt Europese motieven. Deze kindersarong is gemaakt door Indo-Europese batikkers voor gebruik door alle culturele groepen."),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/994622'): rdflib.term.Literal('Credits: Collectie Tillema'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/423086'): rdflib.term.Literal('Credits: Collectie Nationaal Museum van Wereldculturen - afkomstig uit de collectie van het Indisch Wetenschappelijk Instituut (IWI) / donated by the Indisch Wetenschappelijk Instituut (IWI)'),
#  rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/169535'): rdflib.term.Literal("Door (Indo-)Europeanen gebatikte kokerrok in rood, twee tinten blauw, bruin (rood met blauw) op crème. De badan is overwegend rood, terwijl de kepala blauw is. De doek heeft een zogenoemde kepala dlorong: met een sierlijke diagonaal in het midden, die twee chrysantboeketten scheidt, de ene is ondersteboven afgebeeld, alles op een achtergrond van kleine stippen . De kepala en de onderkant van de badan is afgezet met kashmirachtige motieven, buta, die een beetje lijken op het traditionele lar-motief van de enkele vleugel. De rode badan ('lichaam') heeft bloemranken met grote bloemen en kleine bloemslingers, bulan volgens Veldhuisen, booh volgens Heringa (1996). Chrysanten staan in de Chinese symboliek voor de herfst, en wordt dan ook geassocieerd met die fase in een mensenleven: de middelbare leeftijd (Heringa, 1996). De doek had een katoenen band aan de bovenkant bevestigd en is gemaakt voor gebruik door alle culturele groepen, vandaar de combinatie van verschillende culturele symbolen."),
#  ...}

# %%
obj_graph.namespace_manager.qname(rdflib.term.URIRef('https://hdl.handle.net/20.500.11840/757753'))
# Out:
# 'ns3:757753'

# %% [markdown]
# ### .1 Extract descriptions
#
# (keep links)

# %%
q = """SELECT ?a ?b
       WHERE {
          # ?a dc:description ?b .
       }"""

descriptions = {obj: obj_graph.query(q)

# %%
dir(descriptions[0][1])
descriptions[0][0], descriptions[0][1].normalize(), """
aant JH: film War Paint met Tim McCoy Arapaho Ind. achterop foto stempel met gegevens film: "Tim McCoy in War Paint with Pauline Starke & Karl Dane. directed by W.S.Vandyke. A metro-Goldwyn-Mayer Picture. Country of origin U.S.A."
"""

# %%
descriptions
